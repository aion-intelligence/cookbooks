# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import json
import logging
from pathlib import Path

from utils.gpu import check_gpu
from utils.ui import create_input_ui, display_ui
from utils.chai.download import download_chai_models
from utils.chai.prediction_and_viz import run_prediction_and_viz


logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

MODELS_DIR = Path("./runs/chai/models")
OUTPUT_DIR = Path("./runs/chai/outputs")
os.environ["HF_TOKEN"] = "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"

check_gpu()  # Check GPU availability
# Out:
# WARNING:utils.gpu:⚠️  No GPU detected - prediction will be slow

# %%
logger.info("Step 1: Downloading models")
download_chai_models(models_dir=MODELS_DIR)
# Out:
# INFO:__main__:Step 1: Downloading models
# INFO:utils.chai.download:Downloading Chai-1 models to runs/chai/models
# INFO:utils.chai.download:Revision: main
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/chaidiscovery/chai-1/revision/main "HTTP/1.1 200 OK"
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# INFO:utils.chai.download:Model download complete

# %%
# create UI components
ui_components = create_input_ui()

# create prediction function that can be attached to run button
run_prediction_args = (MODELS_DIR, OUTPUT_DIR, ui_components)
run_prediction_fn = lambda b: run_prediction_and_viz(b, *run_prediction_args)

ui_components["run_button"].on_click(run_prediction_fn)

# %%
# Display UI
display_ui("Chai", ui_components)
# Out:
# <h3>Boltz-2 Structure Prediction Interface</h3>
# HBox(children=(Button(button_style='info', description='Load Insulin Example', style=ButtonStyle()), Button(bu…
# Textarea(value='sequences:\n  - protein:\n      id: [A]\n      sequence: GIVEQCCTSICSLYQLENYCN\n  - protein:\n…
# Checkbox(value=True, description='Run new prediction (clear previous results)', indent=False)
# Button(button_style='success', description='Run Prediction', style=ButtonStyle())
# Output()

# %%
print("hi")
# Out:
# hi
