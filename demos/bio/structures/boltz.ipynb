# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import logging
from pathlib import Path

from utils.gpu import check_gpu
from utils.ui import create_input_ui, display_ui
from utils.boltz.download import download_boltz_models
from utils.boltz.prediction_and_viz import run_prediction_and_viz


logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

MODELS_DIR = Path("./runs/boltz/models")
OUTPUT_DIR = Path("./runs/boltz/outputs")

check_gpu()  # Check GPU availability
# Out:
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@rcsb/rcsb-molstar/build/dist/viewer/rcsb-molstar.css">
#     <script src="https://cdn.jsdelivr.net/npm/@rcsb/rcsb-molstar/build/dist/viewer/rcsb-molstar.js"></script>
#     <div id="molstar-preload-status" style="color: #888; font-size: 12px;">Loading Mol* library...</div>
#     <script>
#         setTimeout(function() {
#             var status = document.getElementById('molstar-preload-status');
#             if (typeof rcsbMolstar !== 'undefined') {
#                 status.innerHTML = '✓ Mol* viewer ready';
#                 status.style.color = 'green';
#             } else {
#                 status.innerHTML = '✗ Mol* failed to load - visualizations will not work';
#                 status.style.color = 'red';
#             }
#         }, 2000);
#     </script>
# WARNING:utils.gpu:⚠️  No GPU detected - prediction will be slow

# %%
logger.info("Step 1: Downloading models")
download_boltz_models(models_dir=MODELS_DIR)
# Out:
# INFO:__main__:Step 1: Downloading models
# INFO:utils.boltz.download:Downloading Boltz-2 models to runs/boltz/models
# INFO:utils.boltz.download:Revision: 6fdef46d763fee7fbb83ca5501ccceff43b85607
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/boltz-community/boltz-2/revision/6fdef46d763fee7fbb83ca5501ccceff43b85607 "HTTP/1.1 200 OK"
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/boltz-community/boltz-2/resolve/6fdef46d763fee7fbb83ca5501ccceff43b85607/.gitattributes "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/boltz-community/boltz-2/resolve/6fdef46d763fee7fbb83ca5501ccceff43b85607/boltz2_conf.ckpt "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/boltz-community/boltz-2/resolve/6fdef46d763fee7fbb83ca5501ccceff43b85607/mols.tar "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/boltz-community/boltz-2/resolve/6fdef46d763fee7fbb83ca5501ccceff43b85607/README.md "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/boltz-community/boltz-2/resolve/6fdef46d763fee7fbb83ca5501ccceff43b85607/boltz2_aff.ckpt "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/boltz-community/boltz-2/6fdef46d763fee7fbb83ca5501ccceff43b85607/.gitattributes "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/boltz-community/boltz-2/6fdef46d763fee7fbb83ca5501ccceff43b85607/README.md "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/boltz-community/boltz-2/xet-read-token/6fdef46d763fee7fbb83ca5501ccceff43b85607 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/boltz-community/boltz-2/xet-read-token/6fdef46d763fee7fbb83ca5501ccceff43b85607 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/boltz-community/boltz-2/xet-read-token/6fdef46d763fee7fbb83ca5501ccceff43b85607 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/boltz-community/boltz-2/6fdef46d763fee7fbb83ca5501ccceff43b85607/.gitattributes "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/boltz-community/boltz-2/6fdef46d763fee7fbb83ca5501ccceff43b85607/README.md "HTTP/1.1 200 OK"

# %%
# create UI components and attach prediction to Run button
ui_components = create_input_ui()

run_prediction_args = (MODELS_DIR, OUTPUT_DIR, ui_components)
run_prediction_fn = lambda b: run_prediction_and_viz(b, *run_prediction_args)

ui_components["run_button"].on_click(run_prediction_fn)

# %%
# Display UI
display_ui("Boltz-2", ui_components)
# Out:
# <h3>Boltz-2 Structure Prediction Interface</h3>
# HBox(children=(Button(button_style='info', description='Load Insulin Example', style=ButtonStyle()), Button(bu…
# Textarea(value='sequences:\n  - protein:\n      id: [A]\n      sequence: GIVEQCCTSICSLYQLENYCN\n  - protein:\n…
# Checkbox(value=True, description='Run new prediction (clear previous results)', indent=False)
# Button(button_style='success', description='Run Prediction', style=ButtonStyle())
# Output()
